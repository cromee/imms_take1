# %%
그럼 지금부터는 캐치테이블이 플랫폼을 어떻게 성공적으로 구축하고 있는지 플랫폼을 이루는 3요소 측면에서 살펴보도록 하겠습니다. 

우선 플랫폼이 제대로 구축되고 교차네트워크가 발생하기 위해서는 3가지 요건이 충족되어야 합니다. 

첫째 플랫폼은 둘 이상의 서로 다른 그룹의 사용자들 간의 거래를 중재할 수 있어야 하며 이를 양면시장 플랫폼이라고 합니다.  캐치테이블의 경우 식당을 보조금을 지원하는 Subsidizing segment로, 그리고 식당을 이용하는 고객을 Subsidized segment로 하여 양면시장을 구성하였습니다. 
캐치테이블의 경우 테이블 노트 라는 매장관리 솔루션을 먼저 런칭하여  매장의 공간정보와 실시간 테이블 정보를 모을 수 있었습니다.  이를 통해 돈을 지불하는 이용자 그룹을 먼저 확보 함으로써 수익의 리스크를 줄일 수있었습니다.

둘째로 양쪽의 그룹을 플랫폼에 락인할 수 있는 교차보조 도구가 필요합니다.  플랫폼이 식당과 소비자 모두가 만족할 만한 기능을 제공함으로써 양면시장을 견고히 할 수 있고 그것이 교차 네트워크에 도움이 되는 경우, 이러한 기능들을 교차보조 도구라고 할 수 있습니다. 캐치테이블의 경우 식당측에는 고객정보 관리 및 전화문의의 불편함과 노쇼를 방지 하는 효과를 그리고 사용자 측에는 예약가능 여부와 실시간 빈자리 등의 정보를 통한 예약 편의 기능을 제공하여 이를 충족하고 있습니다.  

마지막으로 플랫폼은 보조금을 제공할 그룹을 선정하고 가격차별화를 통한 수익창출을 기대할 수 있어야 합니다. 앞서 소개 했듯이 캐치 테이블은 식당예약 횟수에 따라 식당쪽에 구독료를 부과합니다. 
월 구독료는 최대 10만원 정도인데 비해, 2021넨 12월 통계에 따르면 가맹점 월평균 매출의 1/3이 캐치테이블 예약을 통해 발생되는 것으로 나타났습니다. 이는 지속적으로 paying-side의 유입원으로 작용할 것으로 보입니다. 

이렇게 세가지 플랫폼의 구성요소를 충족함으로써 교차네트워크 효과를 확인 할 수 있었는데요, 
(그래프 설명 )2021년 9월 부터 2021년 B2C MAU가 약 4만에서 12만으로 3배 증가함에 따라 B2B 가맹점의 신규 인입 역시 30에서 98로 동일하게 3배 증가 하는 것을 보실 수 있습니다. 

(다음장)
이런 네트워크 효과를 기반으로 캐치 테이블의 선순환 고리를 삭스 냅킨 스케치에 기반하여 그려보았습니다. 
우선 와드 사는 테이블 노트 라는 매장관리 솔루션을 통해 레스토랑 가입을 유도 했습니다. 가입 레스토랑이 늘어날 수록 실시간 예약 정보와 매장 정보를 더 많이 축적할 수 있었고, 이런 정보를 바탕으로 런칭한 캐치테이블 어플을 통해 소비자는 레스토랑의 예약 가능 여부와 실시간 빈자리 확인등은  확인하여 더욱 쉬운 예약서비스를 사용할 수 있었습니다. 사용자의 예약이 늘어나고 식당에서도 사용자의 유입경로와 이용시간을 조절할 수 있게 되면서 매장 테이블 회전율을 높일 수 있었습니다. 가령 예약이 적은 시간대에 happy hour 같은 프로모션을 제공할 수 있는데 이는 또 소비자에게 추가적인 할인혜택으로 돌아갈 수 있었습니다. 그리하여 더 많은 고객이 서비스를 이용하게 되고, 앞서  그래프에서 보았듯 고객의 수가 늘어남에 따라 가맹점의 수도 함께 증가하는 선순환 고리를 완성할 수 있었습니다. 
(교차도구 상세는 첨부로 빼거나 삭제 해도 될듯)

(다음장) 
이렇게 이루어진 선순환 구조를 통해 캐치 테이블의 성장을 확인 할 수 있는 몇 가지 척도를 준비해봤습니다.
(강조) 10배 성장했습니다.
2022년 8월 기준 캐치테이블의 가맹점 수는 4000개 이상으로 업계 1위를 차지하고 있습니다. 이는 2018년 403개에서 10배 성장 한 값입니다. 또 예약 방문수 역시 2018년 8.9만에서 2022년 79.8만으로 10배 성장했습니다. 
(다음장)
(강조) 또 10배 낮췄습니다. 2022년 캐치테이블의 MAU는 140만 이상입니다. 그래프를 보시면 MAU가 처음 60만을 달성하기 까지는 496일이 걸렸지만 그 다음 60만을 늘려 120만이 되기 까지는 47일만 소요되었습니다. 이렇게 사용자수가 2배 늘어나기 까지 걸리는 시간이 10배나 줄었습니다. 
(다음장)
그밖에도 예약완료수를 보면 2020년 12월 만건에서 2021년 12월 12만건으로 1년 만에 1200% 성장했으며, 캐치테이블을 통해 사용자가 지불하는 예약금 선결제 금액의  2020년에 확인한 전년 동기 대비 증감률 Yoy가 190%인데 ㅣ해 2021년 확인한 yoy는 245%성장하여 129억원에 달하는 것으로 나타났습니다. 

마무리 : 캐치테이블이 식당예약 플랫폼으로서 이렇게 성장을 거듭하고 있지만 아직 영업이익률 -30억을 기록하고 있습니다. 앞서 잠시 설명 드렸듯이 저희는 캐치 테이블이 새롭게 진행할 수 있는 비즈니스 모델이 어떤것들이 있을지 더 고민해보았습니다.
